# %%
#Problem Statement 1
#4.Most complex code have written
bike = input("Enter the bike you want : ")
model = input("Enter the Model : ")
colour = input("Enter the Colour : ")
if bike == "Hardly Davidson" or bike == "hardly davidson" or bike == "HARDLY DAVISON":
    if model == "Roadster":
        if colour == "Red" or colour == "Blue" or colour == "Black" or colour == "Navy Blue":
            print("Cool Bike! It's really good for long travel and mountain ride")
        elif colour == "Orange" or colour == "Violet" or colour == "Green":
            print("Great bike It's really awesome")
        else:
            print("We didn't have the color of that bike")
    elif model == "Rpg1250":
        if colour == "Red" or colour == "Blue" or colour == "Black" or colour == "Navy Blue":
            print("Great really good")
        elif colour == "Orange" or colour == "Violet" or colour == "Green":
            print("It's so cool")
        else:
            print("We didn't have the color of that bike")
    else:
        print("We didn't have that model it will come next week.Sorry for the inconvinience")
elif bike == "Royal Enfield" or bike == "royal enfield" or bike == "ROYAL ENFIELD":
    if model == "Classic 350":
        if colour == "Red" or colour == "Blue" or colour == "Black" or colour == "Navy Blue":
            print("It's one of my favourite bikes in my childhood")
        elif colour == "Orange" or colour == "Violet" or colour == "Green":
            print("I literally like the bike because of its model and its function")
        else:
            print("We didn't have the color of that bike")
    elif model == "Classic 500":
        if colour == "Red" or colour == "Blue" or colour == "Black" or colour == "Navy Blue":
            print("Cool bike")
        elif colour == "Orange" or colour == "Violet" or colour == "Green":
            print("Great")
        else:
            print("We didn't have the color of that bike")
    else:
        print("We didn't have that model it will come next week.Sorry for the inconvinience")
else:
    print("Sorry for the inconvinience we didn't have the model and colour that you have requested")
# Out:
# Enter the bike you want :  Hardly Davidson
# Enter the Model :  Roadster
# Enter the Colour :  Orange
# Great bike It's really awesome
